# %%
# !pipenv install missingno
# Out:
# Installing missingno…
# Adding missingno to Pipfile's [packages]…
# ✔ Installation Succeeded
# Pipfile.lock (3e480f) out of date, updating to (cffb8c)…
# Locking [dev-packages] dependencies…
# ✔ Success!
# Locking [packages] dependencies…
# ✔ Success!
# Updated Pipfile.lock (3e480f)!
# Installing dependencies from Pipfile.lock (3e480f)…
#   🐍   ▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉ 84/84 — 00:00:13mmmmmmmmmmmmmmmmmmmmmmmmmmmmmmm

# %%
from crawto.CrawtoDS import CrawtoDS

# %%
df = pd.read_csv("train.csv")
c = CrawtoDS(
    data=df,
    target="Survived",
    problem='classification'
)

# %%
import missingno as msno
msno.matrix(c.train_data)

# %%
fig, axes = plt.subplots(nrows=2)
ax = msno.matrix(c.train_data)
ax = msno.bar(c.train_data)

# %%
msno.heatmap(c.train_data)
