# %%
import pandas as pd
from CrawtoDS import CrawtoDS

# %%
df = pd.read_csv("../train.csv")
c = CrawtoDS(
    data=df,
    target="Survived",
    problem='classification'
)

# %%
c.nan_report()
# Out:
#              Percent of data encoded NAN
# PassengerId                         0.00
# Survived                            0.00
# Pclass                              0.00
# Name                                0.00
# Sex                                 0.00
# Age                                19.87
# SibSp                               0.00
# Parch                               0.00
# Ticket                              0.00
# Fare                                0.00
# Cabin                              77.10
# Embarked                            0.22

# %%
c.correlation_report()
# Out:
# 'No Features are correlated above the threshold'

# %%
c.target_distribution_report()

# %%
#c.categorical_bar_plots()

# %%
c.numeric_boxplot()

# %%
c.numeric_columns_distribution_report()
# Out:
#           Shapiro-Wilks_Test_Statistic  Shapiro-Wilks_p_Value  \
# Pclass                        0.716527           4.252271e-32
# Age                                NaN           1.000000e+00
# SibSp                         0.505867           1.947132e-39
# Parch                         0.543425           2.408233e-38
# Fare                          0.493863           9.007056e-40
# Survived                      0.616424           5.400153e-36
#
#           Normal distribution ?
# Pclass                    False
# Age                        True
# SibSp                     False
# Parch                     False
# Fare                      False
# Survived                  False

# %%
c.probability_plots()

# %%
c.baseline_prediction()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76       137
#            1       0.00      0.00      0.00        86
#
#     accuracy                           0.61       223
#    macro avg       0.31      0.50      0.38       223
# weighted avg       0.38      0.61      0.47       223

# %%
c.transformed_regression()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.450313
#          Iterations: 35
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Survived   No. Observations:                  668
# Model:                          Logit   Df Residuals:                      655
# Method:                           MLE   Df Model:                           12
# Date:                Tue, 01 Oct 2019   Pseudo R-squ.:                  0.3235
# Time:                        01:02:36   Log-Likelihood:                -300.81
# converged:                      False   LL-Null:                       -444.64
# Covariance Type:            nonrobust   LLR p-value:                 1.826e-54
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Pclass_target_encoded      -2.6849      3.585     -0.749      0.454      -9.711       4.341
# Sex_target_encoded         62.3573      5.592     11.152      0.000      51.398      73.317
# Age_target_encoded         -0.8414      0.729     -1.154      0.249      -2.271       0.588
# SibSp_target_encoded      -12.7545      3.523     -3.620      0.000     -19.659      -5.850
# Parch_target_encoded      -51.6750      7.617     -6.784      0.000     -66.605     -36.745
# Embarked_target_encoded     4.2582      3.195      1.333      0.183      -2.004      10.520
# Pclass_imputed_yj          -0.5431      0.188     -2.890      0.004      -0.911      -0.175
# Age_imputed_yj             -0.4650      0.121     -3.839      0.000      -0.702      -0.228
# SibSp_imputed_yj           -0.5328      0.170     -3.140      0.002      -0.865      -0.200
# Parch_imputed_yj           -0.2179      0.131     -1.657      0.097      -0.476       0.040
# Fare_imputed_yj             0.2779      0.180      1.542      0.123      -0.075       0.631
# missing_Age                -0.3117      0.277     -1.123      0.261      -0.856       0.232
# missing_Embarked           17.6264   1.98e+04      0.001      0.999   -3.87e+04    3.88e+04
# ===========================================================================================
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.450313
#          Iterations: 35
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82       137
#            1       0.71      0.73      0.72        86
#
#     accuracy                           0.78       223
#    macro avg       0.77      0.77      0.77       223
# weighted avg       0.78      0.78      0.78       223
