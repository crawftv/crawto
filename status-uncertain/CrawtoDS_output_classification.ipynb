# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import pandas as pd
from crawto.CrawtoDS import CrawtoDS

# %%
df = pd.read_csv("train.csv")
test= pd.read_csv("test.csv")
c = CrawtoDS(
    data=df,
    test_data=test,
    target="Survived",
    problem='binary classification'
)

# %%
c.nan_report()
# Out:
#              Percent of data encoded NAN
# PassengerId                         0.00
# Survived                            0.00
# Pclass                              0.00
# Name                                0.00
# Sex                                 0.00
# Age                                19.87
# SibSp                               0.00
# Parch                               0.00
# Ticket                              0.00
# Fare                                0.00
# Cabin                              77.10
# Embarked                            0.22

# %%
c.skew_report()
# Out:
# There are 0 highly skewed data columns. Please check them for miscoded na's
# []

# %%
c.correlation_report()
# Out:
# 'No Features are correlated above the threshold'

# %%
c.target_distribution_report()

# %%
c.tsne()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-acd835ead2d5> in <module>
# ----> 1 c.tsne()
#
# AttributeError: 'CrawtoDS' object has no attribute 'tsne'

# %%
#c.categorical_bar_plots()

# %%
c.numeric_boxplot()

# %%
c.probability_plots()

# %%
c.baseline_prediction()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76       137
#            1       0.00      0.00      0.00        86
#
#     accuracy                           0.61       223
#    macro avg       0.31      0.50      0.38       223
# weighted avg       0.38      0.61      0.47       223

# %%
 p= c.transformed_regression()

# %%
p.display
# Out:
#         <head>
#                 <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/semantic-ui@2.4.2/dist/semantic.min.css">
#                 <script src="https://code.jquery.com/jquery-3.1.1.min.js"
#                   integrity="sha256-hVVnYaiADRTO2PzUGmuLJr8BLUSjGIZsDYGmIJLv2b8="
#                   crossorigin="anonymous"></script>
#                 <script src="https://cdn.jsdelivr.net/npm/semantic-ui@2.4.2/dist/semantic.min.js"></script>
#                 <script>require.config({
#                     shim: {
#                         'chartjs': {
#                             deps: ['moment']    // enforce moment to be loaded before chartjs
#                         }
#                     },
#                     paths: {
#                     'chartjs': 'https://cdnjs.cloudflare.com/ajax/libs/Chart.js/2.8.0/Chart.min.js',
#                     'moment': 'https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.24.0/moment.min.js'
#                     }});
#                     </script>
#         </head>
#
#         <body>
#
#     <div class="ui statistics">
#
#         <div class="statistic">
#         <div class="value">
#         50.98
#         </div>
#         <div class="label">
#         Average Precision Score
#         </div>
#         </div>
#
#         <div class="statistic">
#         <div class="value">
#         65.16
#         </div>
#         <div class="label">
#         ROC AUC Score
#         </div>
#         </div>
#
#     </div>
#
#             <div class= "ui grid">
#
#         <div class= "eight wide column">
#         <h2>Classification Report</h2>
#         <table class="ui celled table">
#           <thead>
#             <tr>
#             <th></th>
#             <th>Precision</th>
#             <th>Recall</th>
#             <th>F1-Score</th>
#             <th>Support</th>
#           </tr></thead>
#           <tbody>
#               <tr><td data-label="">0</td><td data-label="Precision">0.71</td><td data-label="Precision">0.86</td><td data-label="Precision">0.78</td><td data-label="Precision">137</td></tr><tr><td data-label="">1</td><td data-label="Precision">0.67</td><td data-label="Precision">0.44</td><td data-label="Precision">0.53</td><td data-label="Precision">86</td></tr><tr><td data-label="">macro avg</td><td data-label="Precision">0.69</td><td data-label="Precision">0.65</td><td data-label="Precision">0.66</td><td data-label="Precision">223</td></tr><tr><td data-label="">weighted avg</td><td data-label="Precision">0.69</td><td data-label="Precision">0.7</td><td data-label="Precision">0.68</td><td data-label="Precision">223</td></tr>
#           </tbody>
#         </table>
#         </div>
#         <div class= "eight wide column">
#         <h2>Confusion Matrix</h2>
#         <table class="ui celled table">
#           <thead>
#             <tr>
#             <th></th> <th> Predicted 0 </th> <th> Predicted 1 </th>
#           </tr></thead>
#           <tbody>
#               <tr><td data-label="">Actual 0</td><td data-label="Predicted 0">118</td><td data-label="Predicted 1">19</td></tr><tr><td data-label="">Actual 1</td><td data-label="Predicted 0">48</td><td data-label="Predicted 1">38</td></tr>
#           </tbody>
#         </table>
#         </div>
#         <div class = 'eight wide column'>
#         <canvas id= "1d9e2642-4edd-11ea-88f2-0c9d92106694" width="1" height="1" ></canvas>
#         <script>
#         requirejs(['https://cdnjs.cloudflare.com/ajax/libs/Chart.js/2.8.0/Chart.js'], function(Chart){
#             new Chart(document.getElementById("1d9e2642-4edd-11ea-88f2-0c9d92106694"), {
#                     type: "line",
#                     data: {"datasets": [{"label": "ROC Curve", "data": [{"x": 0.0, "y": 0.0}, {"x": 0.0, "y": 0.011627906976744186}, {"x": 0.0, "y": 0.03488372093023256}, {"x": 0.0072992700729927005, "y": 0.03488372093023256}, {"x": 0.0072992700729927005, "y": 0.05813953488372093}, {"x": 0.014598540145985401, "y": 0.05813953488372093}, {"x": 0.014598540145985401, "y": 0.06976744186046512}, {"x": 0.021897810218978103, "y": 0.06976744186046512}, {"x": 0.021897810218978103, "y": 0.10465116279069768}, {"x": 0.029197080291970802, "y": 0.10465116279069768}, {"x": 0.029197080291970802, "y": 0.20930232558139536}, {"x": 0.0364963503649635, "y": 0.20930232558139536}, {"x": 0.0364963503649635, "y": 0.22093023255813954}, {"x": 0.043795620437956206, "y": 0.22093023255813954}, {"x": 0.043795620437956206, "y": 0.23255813953488372}, {"x": 0.051094890510948905, "y": 0.23255813953488372}, {"x": 0.051094890510948905, "y": 0.2441860465116279}, {"x": 0.058394160583941604, "y": 0.2441860465116279}, {"x": 0.058394160583941604, "y": 0.2558139534883721}, {"x": 0.072992700729927, "y": 0.2558139534883721}, {"x": 0.072992700729927, "y": 0.27906976744186046}, {"x": 0.08029197080291971, "y": 0.27906976744186046}, {"x": 0.08029197080291971, "y": 0.313953488372093}, {"x": 0.08759124087591241, "y": 0.313953488372093}, {"x": 0.08759124087591241, "y": 0.32558139534883723}, {"x": 0.10948905109489052,

# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.83      0.82       137
#            1       0.72      0.70      0.71        86
#
#     accuracy                           0.78       223
#    macro avg       0.77      0.76      0.77       223
# weighted avg       0.78      0.78      0.78       223

# %%
c.transformed_random_forest()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85       137
#            1       0.78      0.71      0.74        86
#
#     accuracy                           0.81       223
#    macro avg       0.80      0.79      0.80       223
# weighted avg       0.81      0.81      0.81       223

# %%
c.transformed_gradient_booster()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87       137
#            1       0.82      0.73      0.77        86
#
#     accuracy                           0.83       223
#    macro avg       0.83      0.82      0.82       223
# weighted avg       0.83      0.83      0.83       223

# %%
list(zip(c.train_transformed_data.columns,c._transformed_svm.coef_[0]))
# Out:
# [('Pclass_target_encoded', 1.1157593776659815),
#  ('Sex_target_encoded', -7.552902596238283),
#  ('Age_target_encoded', 0.14653694003063364),
#  ('SibSp_target_encoded', -0.31274881601296906),
#  ('Parch_target_encoded', -0.05334772765904538),
#  ('Embarked_target_encoded', -1.198176902556602),
#  ('Fare_imputed_yj', 0.25765261903743475),
#  ('missing_Age', -0.029432894694155096),
#  ('missing_Embarked', 0.36577050961681373)]

# %%
c.transformed_svm()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.85      0.81       137
#            1       0.71      0.59      0.65        86
#
#     accuracy                           0.75       223
#    macro avg       0.74      0.72      0.73       223
# weighted avg       0.75      0.75      0.74       223

# %%
c.test_transformed_data
# Out:
#      Pclass_target_encoded  Sex_target_encoded  Age_target_encoded  \
# 0                 0.372760            0.404255            0.383234
# 1                 0.372760            0.344633            0.499894
# 2                 0.445545            0.404255            0.632881
# 3                 0.372760            0.404255            0.428459
# 4                 0.372760            0.344633            0.358333
# ..                     ...                 ...                 ...
# 413               0.372760            0.404255            0.358333
# 414               0.357143            0.344633            0.624780
# 415               0.372760            0.404255            0.383234
# 416               0.372760            0.404255            0.358333
# 417               0.372760            0.404255            0.358333
#
#      SibSp_target_encoded  Parch_target_encoded  Embarked_target_encoded  \
# 0                0.402299              0.393862                 0.441860
# 1                0.344828              0.393862                 0.399449
# 2                0.402299              0.393862                 0.441860
# 3                0.402299              0.393862                 0.399449
# 4                0.344828              0.300000                 0.399449
# ..                    ...                   ...                      ...
# 413              0.402299              0.393862                 0.399449
# 414              0.402299              0.393862                 0.300000
# 415              0.402299              0.393862                 0.399449
# 416              0.402299              0.393862                 0.399449
# 417              0.344828              0.300000                 0.300000
#
#      Fare_imputed_yj  missing_Age  missing_Embarked
# 0          -0.787200            0                 0
# 1          -0.898051            0                 0
# 2          -0.575263            0                 0
# 3          -0.686680            0                 0
# 4          -0.338030            0                 0
# ..               ...          ...               ...
# 413        -0.759589            1                 0
# 414         1.739234            0                 0
# 415        -0.863359            0                 0
# 416        -0.759589            1                 0
# 417         0.255534            1                 0
#
# [418 rows x 9 columns]
