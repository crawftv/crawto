# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import pandas as pd
from crawto.CrawtoDS import CrawtoDS

# %%
df = pd.read_csv("train.csv")
test= pd.read_csv("test.csv")
c = CrawtoDS(
    data=df,
    test_data=test,
    target="Survived",
    problem='binary classification'
)

# %%
c.nan_report()
# Out:
#              Percent of data encoded NAN
# PassengerId                         0.00
# Survived                            0.00
# Pclass                              0.00
# Name                                0.00
# Sex                                 0.00
# Age                                19.87
# SibSp                               0.00
# Parch                               0.00
# Ticket                              0.00
# Fare                                0.00
# Cabin                              77.10
# Embarked                            0.22

# %%
c.missing_suite()

# %%
c.skew_report()
# Out:
# There are 0 highly skewed data columns. Please check them for miscoded na's
# []

# %%
c.correlation_report()
# Out:
# 'No Features are correlated above the threshold'

# %%
c.target_distribution_report()

# %%
c.tsne()
# Out:
#             <head>
#                 <script type="application/javascript" src="https:\cdnjs.cloudflare.com/ajax/libs/require.js/x.y.z/require.js"></script>
#             </head>
#             <body>
#             <h1> T-sne </h1>
#             <canvas id="t-sne-chart"></canvas>
#             <script>
#             requirejs(['https:\cdnjs.cloudflare.com/ajax/libs/Chart.js/2.8.0/Chart.js'], function(Chart){
#                 new Chart(document.getElementById("t-sne-chart"), {
#                         type: "scatter",
#                         data: {"datasets": [{"label": "0", "data": [{"x": -32.394264221191406, "y": -3.8283300399780273}, {"x": 10.75283145904541, "y": -19.754287719726562}, {"x": 4.75419807434082, "y": -29.95144271850586}, {"x": 17.851041793823242, "y": 13.461654663085938}, {"x": -20.61650848388672, "y": 30.965972900390625}, {"x": 37.72618103027344, "y": -9.724693298339844}, {"x": -26.811410903930664, "y": -0.04119277745485306}, {"x": 34.8759880065918, "y": -11.4266357421875}, {"x": -28.61784553527832, "y": -10.787607192993164}, {"x": 6.553912162780762, "y": 17.52826499938965}, {"x": -29.301876068115234, "y": -5.279822826385498}, {"x": 10.556632041931152, "y": -14.77322769165039}, {"x": 10.624683380126953, "y": -11.587547302246094}, {"x": 9.556205749511719, "y": 5.959500312805176}, {"x": -29.393476486206055, "y": -5.243556976318359}, {"x": -0.013543818145990372, "y": -36.266845703125}, {"x": 11.249191284179688, "y": -9.906517028808594}, {"x": 35.205020904541016, "y": -13.514896392822266}, {"x": -28.799745559692383, "y": -10.143509864807129}, {"x": 34.731876373291016, "y": -9.129602432250977}, {"x": -26.656923294067383, "y": 1.0021334886550903}, {"x": -30.270442962646484, "y": -3.868126392364502}, {"x": -5.8795061111450195, "y": 43.37456130981445}, {"x": -5.309048652648926, "y": 43.493560791015625}, {"x": -0.9548721313476562, "y": -42.41647720336914}, {"x": -0.949928343296051, "y": -42.41295623779297}, {"x": 4.462684154510498, "y": -30.678478240966797}, {"x": -28.931686401367188, "y": -10.874070167541504}, {"x": 25.63787269592285, "y": -3.484205961227417}, {"x": -25.536367416381836, "y": 0.7067707180976868}, {"x": -14.634286880493164, "y": 0.6865233778953552}, {"x": -33.899200439453125, "y": -3.704303503036499}, {"x": -28.936216354370117, "y": -8.255209922790527}, {"x": 15.986390113830566, "y": 10.568819046020508}, {"x": -6.236131191253662, "y": 39.388492584228516}, {"x": 18.018762588500977, "y": 13.7713623046875}, {"x": 10.377767562866211, "y": 6.644344806671143}, {"x": 3.6503746509552, "y": -31.139354705810547}, {"x": 15.026741981506348, "y": 9.9823579788208}, {"x": 12.088476181030273, "y": -15.481559753417969}, {"x": 0.44986942410469055, "y": 14.451284408569336}, {"x": 11.012568473815918, "y": -16.51375961303711}, {"x": -0.9971060752868652, "y": -39.55241394042969}, {"x": 38.91657257080078, "y": -4.700936794281006}, {"x": 12.057074546813965, "y": -14.452860832214355}, {"x": 3.8503024578094482, "y": -35.30921173095703}, {"x": -14.873856544494629, "y": 0.19787441194057465}, {"x": -20.062828063964844, "y": 30.54076385498047}, {"x": -19.403079986572266, "y": 30.567556381225586}, {"x": 38.91731643676758, "y": -4.699700355529785}, {"x": 11.229146957397461, "y": -9.606363296508789}, {"x": 2.6412463188171387, "y": 15.650400161743164}, {"x": 2.73376727104187, "y": 15.33037281036377}, {"x": -27.967384338378906, "y": -9.912970542907715}, {"x": 0.06565400958061218, "y": -37.394596099853516}, {"x": -28.99433135986328, "y": -9.124543190002441}, {"x": 36.11201095581055, "y": -7.585996150970459}, {"x": 2.6631319522857666, "y": -32.929237365722656}, {"x": -31.99409294128418, "y": -4.043505668640137}, {"x": -24.06812858581543, "y": 1.5971770286560059}, {"x": -16.35088348388672, "y": 33.1392936706543}, {"x": 9.897966384887695, "y": -19.332504272460938}, {"x": -5.9740471839904785, "y": 43.81708526611328}, {"x": 14.086280822753906, "y": 9.120006561279297}, {"x": -18.709896087646484, "y": 29.420740127563477}, {"x": 10.599770545959473, "y": -12.44904899597168}, {"x": 12.877093315124512, "y": -20.44944953918457}, {"x": -2.241189479827881, "y": -38.88615417480469}, {"x": 9.36847972869873, "y": -19.67061996459961}, {"x": -0.5964192748069763, "y": -41.360504150390625}, {"x": 40.55439758300781, "y": -4.3327107429504395}, {"x": 8.934517860412598, "y": -18.88991355895996}, {"x": 11.699646949768066, "y": -13.379764556884766}, {"x": -30.617324829101562, "y": -3.3155288696289062}, {"x": 36.988101959228516, "y": -10.047779083251953}, {"x": -13.2460060119628 ...

# %%
#c.categorical_bar_plots()

# %%
c.numeric_boxplot()

# %%
c.probability_plots()

# %%
c.baseline_prediction()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76       137
#            1       0.00      0.00      0.00        86
#
#     accuracy                           0.61       223
#    macro avg       0.31      0.50      0.38       223
# weighted avg       0.38      0.61      0.47       223

# %%
c.transformed_regression()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.531387
#          Iterations: 35
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Survived   No. Observations:                  668
# Model:                          Logit   Df Residuals:                      655
# Method:                           MLE   Df Model:                           12
# Date:                Thu, 24 Oct 2019   Pseudo R-squ.:                  0.2017
# Time:                        11:48:44   Log-Likelihood:                -354.97
# converged:                      False   LL-Null:                       -444.64
# Covariance Type:            nonrobust   LLR p-value:                 5.822e-32
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Pclass_target_encoded      -4.3469      1.971     -2.205      0.027      -8.211      -0.483
# Sex_target_encoded         54.0566      7.654      7.063      0.000      39.056      69.057
# Age_target_encoded         -0.0467      0.588     -0.079      0.937      -1.199       1.106
# SibSp_target_encoded       -4.0020      2.534     -1.579      0.114      -8.968       0.964
# Parch_target_encoded      -36.5356      6.653     -5.492      0.000     -49.575     -23.496
# Embarked_target_encoded   -10.7584      4.489     -2.397      0.017     -19.556      -1.961
# Pclass_imputed_yj          -0.6733      0.141     -4.775      0.000      -0.950      -0.397
# Age_imputed_yj             -0.3618      0.106     -3.398      0.001      -0.570      -0.153
# SibSp_imputed_yj           -0.2477      0.116     -2.132      0.033      -0.475      -0.020
# Parch_imputed_yj           -1.4766      0.309     -4.779      0.000      -2.082      -0.871
# Fare_imputed_yj             0.5288      0.170      3.118      0.002       0.196       0.861
# missing_Age                 0.1317      0.242      0.544      0.587      -0.343       0.607
# missing_Embarked           18.6258   2.38e+04      0.001      0.999   -4.67e+04    4.67e+04
# ===========================================================================================
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.531387
#          Iterations: 35
#               precision    recall  f1-score   support
#
#            0       0.76      0.86      0.81       137
#            1       0.72      0.56      0.63        86
#
#     accuracy                           0.74       223
#    macro avg       0.74      0.71      0.72       223
# weighted avg       0.74      0.74      0.74       223

# %%
c.transformed_decision_tree()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.83       137
#            1       0.76      0.62      0.68        86
#
#     accuracy                           0.78       223
#    macro avg       0.77      0.75      0.75       223
# weighted avg       0.77      0.78      0.77       223

# %%
c.transformed_random_forest()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.92      0.85       137
#            1       0.83      0.60      0.70        86
#
#     accuracy                           0.80       223
#    macro avg       0.81      0.76      0.77       223
# weighted avg       0.80      0.80      0.79       223

# %%
c.transformed_gradient_booster()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.93      0.87       137
#            1       0.85      0.66      0.75        86
#
#     accuracy                           0.83       223
#    macro avg       0.83      0.79      0.81       223
# weighted avg       0.83      0.83      0.82       223

# %%
list(zip(c.train_transformed_data.columns,c._transformed_svm.coef_[0]))
# Out:
# [('Pclass_target_encoded', -0.7540134911237334),
#  ('Sex_target_encoded', 4.713808583921555),
#  ('Age_target_encoded', 0.12614531220395223),
#  ('SibSp_target_encoded', 0.6750178419489076),
#  ('Parch_target_encoded', -0.9748318402525062),
#  ('Embarked_target_encoded', 0.7362746141102522),
#  ('Pclass_imputed_yj', -0.28185996291243703),
#  ('Age_imputed_yj', -0.16524810305538704),
#  ('SibSp_imputed_yj', -0.03913479228500201),
#  ('Parch_imputed_yj', -0.0012046245480829762),
#  ('Fare_imputed_yj', 0.15459854634810039),
#  ('missing_Age', 0.030788538817347916),
#  ('missing_Embarked', 0.46220511726966496)]

# %%
c.transformed_svm()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.83      0.80       137
#            1       0.69      0.60      0.65        86
#
#     accuracy                           0.74       223
#    macro avg       0.73      0.72      0.72       223
# weighted avg       0.74      0.74      0.74       223

# %%
c.test_transformed_data
# Out:
#      Pclass_target_encoded  Sex_target_encoded  Age_target_encoded  \
# 0                 0.388889            0.387692            0.383234
# 1                 0.388889            0.409357            0.256319
# 2                 0.319588            0.387692            0.000000
# 3                 0.388889            0.387692            0.799949
# 4                 0.388889            0.409357            0.411765
# ..                     ...                 ...                 ...
# 413               0.388889            0.387692            0.380165
# 414               0.477477            0.409357            0.002565
# 415               0.388889            0.387692            0.383234
# 416               0.388889            0.387692            0.380165
# 417               0.388889            0.387692            0.380165
#
#      SibSp_target_encoded  Parch_target_encoded  Embarked_target_encoded  \
# 0                0.404834              0.417112                 0.380952
# 1                0.383333              0.417112                 0.385475
# 2                0.404834              0.417112                 0.380952
# 3                0.404834              0.417112                 0.385475
# 4                0.383333              0.304348                 0.385475
# ..                    ...                   ...                      ...
# 413              0.404834              0.417112                 0.385475
# 414              0.404834              0.417112                 0.437500
# 415              0.404834              0.417112                 0.385475
# 416              0.404834              0.417112                 0.385475
# 417              0.383333              0.304348                 0.437500
#
#      Pclass_imputed_yj  Age_imputed_yj  SibSp_imputed_yj  Parch_imputed_yj  \
# 0             0.849151        0.449825         -0.672521         -0.567787
# 1             0.849151        1.336249          1.390818         -0.567787
# 2            -0.642335        2.337686         -0.672521         -0.567787
# 3             0.849151       -0.113499         -0.672521         -0.567787
# 4             0.849151       -0.506776          1.390818          1.692079
# ..                 ...             ...               ...               ...
# 413           0.849151       -0.036700         -0.672521         -0.567787
# 414          -1.482512        0.775536         -0.672521         -0.567787
# 415           0.849151        0.739744         -0.672521         -0.567787
# 416           0.849151       -0.036700         -0.672521         -0.567787
# 417           0.849151       -0.036700          1.390818          1.692079
#
#      Fare_imputed_yj  missing_Age  missing_Embarked
# 0          -0.809893            0                 0
# 1          -0.926516            0                 0
# 2          -0.588443            0                 0
# 3          -0.704612            0                 0
# 4          -0.342943            0                 0
# ..               ...          ...               ...
# 413        -0.780930            1                 0
# 414         1.695415            0                 0
# 415        -0.889959            0                 0
# 416        -0.780930            1                 0
# 417         0.260121            1                 0
#
# [418 rows x 13 columns]
