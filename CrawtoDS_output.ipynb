# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2

# %%
import pandas as pd
from crawto.CrawtoDS import CrawtoDS

# %%
df = pd.read_csv("train.csv")
c = CrawtoDS(
    data=df,
    target="Survived",
    problem='classification'
)

# %%
c.nan_report()
# Out:
#              Percent of data encoded NAN
# PassengerId                         0.00
# Survived                            0.00
# Pclass                              0.00
# Name                                0.00
# Sex                                 0.00
# Age                                19.87
# SibSp                               0.00
# Parch                               0.00
# Ticket                              0.00
# Fare                                0.00
# Cabin                              77.10
# Embarked                            0.22

# %%
c.missing_suite()

# %%
c.skew_report()
# Out:
# There are 0 highly skewed data columns. Please check them for miscoded na's
# []

# %%
c.correlation_report()
# Out:
# 'No Features are correlated above the threshold'

# %%
c.target_distribution_report()

# %%
c.tsne()
# Out:
#             <head>
#                 <script type="application/javascript" src="https:\cdnjs.cloudflare.com/ajax/libs/require.js/x.y.z/require.js"></script>
#             </head>
#             <body>
#             <h1> T-sne </h1>
#             <canvas id="t-sne-chart"></canvas>
#             <script>
#             requirejs(['https:\cdnjs.cloudflare.com/ajax/libs/Chart.js/2.8.0/Chart.js'], function(Chart){
#                 new Chart(document.getElementById("t-sne-chart"), {
#                         type: "scatter",
#                         data: {"datasets": [{"label": "0", "data": [{"x": 20.38069725036621, "y": 4.619587421417236}, {"x": 3.200896739959717, "y": -27.176311492919922}, {"x": 14.238677978515625, "y": -22.00109100341797}, {"x": -38.69084548950195, "y": 0.4369892477989197}, {"x": -1.1628193855285645, "y": 16.323184967041016}, {"x": -11.85376262664795, "y": -18.22601890563965}, {"x": -1.0895336866378784, "y": 17.07262420654297}, {"x": -11.85781478881836, "y": -18.179279327392578}, {"x": -3.060168504714966, "y": -16.662961959838867}, {"x": 8.377264976501465, "y": -36.54232406616211}, {"x": 31.27240753173828, "y": -6.5043792724609375}, {"x": 28.958206176757812, "y": 8.445792198181152}, {"x": 13.54041576385498, "y": -22.446557998657227}, {"x": -5.252976894378662, "y": 36.27810287475586}, {"x": 21.551027297973633, "y": 5.81035852432251}, {"x": 3.7544422149658203, "y": -28.1066951751709}, {"x": 28.68572425842285, "y": 8.121808052062988}, {"x": 30.715837478637695, "y": -6.482614994049072}, {"x": 6.445878982543945, "y": -35.49822235107422}, {"x": 4.845139503479004, "y": 20.564956665039062}, {"x": -3.4246108531951904, "y": 36.420387268066406}, {"x": -14.41564655303955, "y": -19.696441650390625}, {"x": -17.759414672851562, "y": -22.859071731567383}, {"x": 23.84775161743164, "y": -2.109424352645874}, {"x": -17.78678321838379, "y": -18.036296844482422}, {"x": 13.942317962646484, "y": -35.64560317993164}, {"x": 0.7631168365478516, "y": 35.784095764160156}, {"x": 7.212072372436523, "y": -9.396280288696289}, {"x": 6.891382217407227, "y": -9.568065643310547}, {"x": 5.408658027648926, "y": -34.86906433105469}, {"x": -14.439737319946289, "y": -18.923994064331055}, {"x": -10.793335914611816, "y": -17.425020217895508}, {"x": 0.9472001791000366, "y": 20.740365982055664}, {"x": 14.133005142211914, "y": -35.424583435058594}, {"x": 21.223308563232422, "y": 5.540061950683594}, {"x": -15.529276847839355, "y": -21.04282569885254}, {"x": 24.909395217895508, "y": 13.343570709228516}, {"x": -12.894905090332031, "y": -20.917173385620117}, {"x": 29.188905715942383, "y": -5.654737949371338}, {"x": -37.124019622802734, "y": -1.4469847679138184}, {"x": -15.69884204864502, "y": -20.082265853881836}, {"x": -25.848718643188477, "y": 10.493268966674805}, {"x": 25.228212356567383, "y": 9.981900215148926}, {"x": 3.6993181705474854, "y": -12.124494552612305}, {"x": -7.351719379425049, "y": 33.65847396850586}, {"x": 5.140738487243652, "y": -10.373025894165039}, {"x": -39.04060745239258, "y": 1.9124618768692017}, {"x": 0.27005520462989807, "y": 38.65199661254883}, {"x": 1.7971867322921753, "y": -13.023890495300293}, {"x": -29.0983829498291, "y": 9.757951736450195}, {"x": 12.263594627380371, "y": -21.55480194091797}, {"x": -1.814234972000122, "y": 17.706443786621094}, {"x": -16.049474716186523, "y": -21.272354125976562}, {"x": -38.34773254394531, "y": 1.6370223760604858}, {"x": -3.241922616958618, "y": 19.386503219604492}, {"x": 3.8914151191711426, "y": -11.531181335449219}, {"x": -24.961427688598633, "y": 8.529703140258789}, {"x": 31.32630157470703, "y": -6.30871057510376}, {"x": -28.747772216796875, "y": 7.992968559265137}, {"x": -3.372255563735962, "y": 19.463130950927734}, {"x": 24.676471710205078, "y": -0.4023013710975647}, {"x": 0.11297143995761871, "y": 32.07733154296875}, {"x": -27.12627601623535, "y": 13.306904792785645}, {"x": -24.709001541137695, "y": 9.017236709594727}, {"x": -12.756802558898926, "y": -16.737091064453125}, {"x": 10.449455261230469, "y": -33.076881408691406}, {"x": 7.620984077453613, "y": -35.79475402832031}, {"x": 31.34636688232422, "y": -6.564225196838379}, {"x": 1.9310568571090698, "y": -13.095653533935547}, {"x": 24.562742233276367, "y": 11.33704662322998}, {"x": -4.110830307006836, "y": 35.554786682128906}, {"x": 4.5501813888549805, "y": -10.178933143615723}, {"x": 28.11892318725586, "y": -4.999639511108398}, {"x": 24.135292053222656, "y": 12.271736145019531}, {"x": -19.61669158935547, "y": -19.801414489746094}, {"x": -2.518249750137329, " ...

# %%
#c.categorical_bar_plots()

# %%
c.numeric_boxplot()

# %%
c.probability_plots()

# %%
c.baseline_prediction()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76       137
#            1       0.00      0.00      0.00        86
#
#     accuracy                           0.61       223
#    macro avg       0.31      0.50      0.38       223
# weighted avg       0.38      0.61      0.47       223

# %%
c.transformed_regression()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: inf
#          Iterations: 35
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-18-24b6a17c1cb2> in <module>
# ----> 1 c.transformed_regression()
#
# /mnt/e/projects/crawto/crawto/CrawtoDS.py in transformed_regression(self)
#     458     def transformed_regression(self):
#     459
# --> 460         print(self._transformed_regressor.summary())
#     461         y_pred_prob = self._transformed_regressor.predict(self.test_transformed_data)
#     462         y_pred = y_pred_prob.apply(lambda x: int(round(x, 0)))
#
# /mnt/e/projects/crawto/crawto/CrawtoDS.py in _transformed_regressor(self)
#     452             lr = Logit(
#     453                 self.train_data[self.target].reset_index(drop=True),
# --> 454                 self.train_transformed_data,
#     455             ).fit()
#     456             return lr
#
# ~/.local/share/virtualenvs/crawto-LwgXxa6A/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#    1900         bnryfit = super(Logit, self).fit(start_params=start_params,
#    1901                 method=method, maxiter=maxiter, full_output=full_output,
# -> 1902                 disp=disp, callback=callback, **kwargs)
#    1903
#    1904         discretefit = LogitResults(self, bnryfit)
#
# ~/.local/share/virtualenvs/crawto-LwgXxa6A/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#     215         mlefit = super(DiscreteModel, self).fit(start_params=start_params,
#     216                 method=method, maxiter=maxiter, full_output=full_output,
# --> 217                 disp=disp, callback=callback, **kwargs)
#     218
#     219         return mlefit # up to subclasses to wrap results
#
# ~/.local/share/virtualenvs/crawto-LwgXxa6A/lib/python3.6/site-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     475             Hinv = cov_params_func(self, xopt, retvals)
#     476         elif method == 'newton' and full_output:
# --> 477             Hinv = np.linalg.inv(-retvals['Hessian']) / nobs
#     478         elif not skip_hessian:
#     479             H = -1 * self.hessian(xopt)
#
# <__array_function__ internals> in inv(*args, **kwargs)
#
# ~/.local/share/virtualenvs/crawto-LwgXxa6A/lib/python3.6/site-packages/numpy/linalg/linalg.py in inv(a)
#     549     signature = 'D->D' if isComplexType(t) else 'd->d'
#     550     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 551     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     552     return wrap(ainv.astype(result_t, copy=False))
#     553
#
# ~/.local/share/virtualenvs/crawto-LwgXxa6A/lib/python3.6/site-packages/numpy/linalg/linalg.py in _raise_linalgerror_singular(err, flag)
#      95
#      96 def _raise_linalgerror_singular(err, flag):
# ---> 97     raise LinAlgError("Singular matrix")
#      98
#      99 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix

# %%
c.transformed_decision_tree()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.84       137
#            1       0.77      0.69      0.72        86
#
#     accuracy                           0.80       223
#    macro avg       0.79      0.78      0.78       223
# weighted avg       0.80      0.80      0.80       223
# test

# %%
c.transformed_random_forest()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.93      0.86       137
#            1       0.85      0.65      0.74        86
#
#     accuracy                           0.82       223
#    macro avg       0.83      0.79      0.80       223
# weighted avg       0.82      0.82      0.81       223

# %%
c.transformed_gradient_booster()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.92      0.88       137
#            1       0.85      0.71      0.77        86
#
#     accuracy                           0.84       223
#    macro avg       0.84      0.81      0.82       223
# weighted avg       0.84      0.84      0.84       223

# %%
list(zip(c.train_transformed_data.columns,c._transformed_svm.coef_[0]))
# Out:
# [('Pclass_target_encoded', -0.2285907195260783),
#  ('Sex_target_encoded', -6.1770080710543045),
#  ('Age_target_encoded', 0.2814654107811524),
#  ('SibSp_target_encoded', -0.15346431754831788),
#  ('Parch_target_encoded', 0.3116582028401724),
#  ('Embarked_target_encoded', -0.7441396741518711),
#  ('Pclass_imputed_yj', -0.2995044939169395),
#  ('Age_imputed_yj', -0.16862741928108504),
#  ('SibSp_imputed_yj', -0.023295248930890803),
#  ('Parch_imputed_yj', -0.029007025304542546),
#  ('Fare_imputed_yj', 0.07182371466598068),
#  ('missing_Age', 0.007568910224045433),
#  ('missing_Embarked', 0.38095394323274945)]

# %%
c.transformed_svm()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87       137
#            1       0.86      0.69      0.76        86
#
#     accuracy                           0.83       223
#    macro avg       0.84      0.81      0.82       223
# weighted avg       0.84      0.83      0.83       223
