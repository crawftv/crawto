# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import pandas as pd
from crawto.CrawtoDS import CrawtoDS

# %%
df = pd.read_csv("train.csv")
c = CrawtoDS(
    data=df,
    target="Survived",
    problem='classification'
)

# %%
c.nan_report()
# Out:
#              Percent of data encoded NAN
# PassengerId                         0.00
# Survived                            0.00
# Pclass                              0.00
# Name                                0.00
# Sex                                 0.00
# Age                                19.87
# SibSp                               0.00
# Parch                               0.00
# Ticket                              0.00
# Fare                                0.00
# Cabin                              77.10
# Embarked                            0.22

# %%
c.correlation_report()
# Out:
# 'No Features are correlated above the threshold'

# %%
c.target_distribution_report()

# %%
c.tsne()
# Out:
#             <head>
#                 <script type="application/javascript" src="https:\cdnjs.cloudflare.com/ajax/libs/require.js/x.y.z/require.js"></script>
#             </head>
#             <body>
#             <h1> T-sne </h1>
#             <canvas id="t-sne-chart"></canvas>
#             <script>
#             requirejs(['https:\cdnjs.cloudflare.com/ajax/libs/Chart.js/2.8.0/Chart.js'], function(Chart){
#                 new Chart(document.getElementById("t-sne-chart"), {
#                         type: "scatter",
#                         data: {"datasets": [{"label": "0", "data": [{"x": -25.353158950805664, "y": -24.382001876831055}, {"x": 13.783120155334473, "y": 27.771268844604492}, {"x": -26.579919815063477, "y": 10.381653785705566}, {"x": 20.581995010375977, "y": 24.21883773803711}, {"x": -26.58932113647461, "y": -24.532724380493164}, {"x": 28.989076614379883, "y": -0.47476789355278015}, {"x": 2.7314605712890625, "y": -25.49130630493164}, {"x": 10.615743637084961, "y": 30.979694366455078}, {"x": 5.504443645477295, "y": 18.758684158325195}, {"x": 7.387993335723877, "y": 14.099349975585938}, {"x": 13.66938304901123, "y": 28.596723556518555}, {"x": 10.414097785949707, "y": 30.36485481262207}, {"x": -22.52425193786621, "y": 8.816987991333008}, {"x": -24.23078155517578, "y": 9.541726112365723}, {"x": -27.353065490722656, "y": -21.260189056396484}, {"x": 22.231155395507812, "y": 23.814130783081055}, {"x": -26.594266891479492, "y": -24.538097381591797}, {"x": -19.13299560546875, "y": -22.887042999267578}, {"x": -3.176215648651123, "y": -15.42860221862793}, {"x": -3.1761858463287354, "y": -15.45820426940918}, {"x": 18.582712173461914, "y": 22.410675048828125}, {"x": -22.443870544433594, "y": 9.02396011352539}, {"x": -5.407497882843018, "y": -10.05302619934082}, {"x": -20.866783142089844, "y": -23.04929542541504}, {"x": -21.569686889648438, "y": -23.123451232910156}, {"x": -22.872230529785156, "y": 8.40907096862793}, {"x": -6.880054473876953, "y": -8.216381072998047}, {"x": 9.914491653442383, "y": 27.338478088378906}, {"x": 6.388180255889893, "y": 19.30445098876953}, {"x": -17.267440795898438, "y": 20.809085845947266}, {"x": 46.27499771118164, "y": -6.009008407592773}, {"x": 22.19740867614746, "y": 25.22035789489746}, {"x": -24.51262664794922, "y": 14.413527488708496}, {"x": -13.74266242980957, "y": 12.688916206359863}, {"x": 1.6318321228027344, "y": -25.995466232299805}, {"x": -18.05695152282715, "y": 18.77721405029297}, {"x": -5.426958084106445, "y": -10.256468772888184}, {"x": -6.928867816925049, "y": -8.002686500549316}, {"x": 43.683650970458984, "y": -8.0784912109375}, {"x": 29.09234046936035, "y": -2.6181795597076416}, {"x": 33.638858795166016, "y": -2.70735764503479}, {"x": 6.371553421020508, "y": 13.61694049835205}, {"x": 0.8355199694633484, "y": -20.204957962036133}, {"x": -29.798446655273438, "y": -24.443296432495117}, {"x": -30.943971633911133, "y": -18.846025466918945}, {"x": -17.46050453186035, "y": 22.765291213989258}, {"x": -6.272955894470215, "y": -11.50566291809082}, {"x": 18.27960205078125, "y": 22.548452377319336}, {"x": 18.3378963470459, "y": 31.191232681274414}, {"x": -5.486229419708252, "y": -21.155418395996094}, {"x": 29.256000518798828, "y": -3.8725244998931885}, {"x": 1.2819184064865112, "y": -23.11587142944336}, {"x": 22.50632667541504, "y": 26.283355712890625}, {"x": -25.852670669555664, "y": 11.675896644592285}, {"x": 13.837730407714844, "y": 28.803787231445312}, {"x": 30.072729110717773, "y": -2.411139488220215}, {"x": 8.235613822937012, "y": 18.950349807739258}, {"x": -1.1948997974395752, "y": -17.67765235900879}, {"x": -18.717851638793945, "y": 8.182772636413574}, {"x": -28.729772567749023, "y": 10.26312255859375}, {"x": 33.07624053955078, "y": -1.875110387802124}, {"x": -18.917543411254883, "y": 22.01301383972168}, {"x": -15.130545616149902, "y": 13.692005157470703}, {"x": -6.409463882446289, "y": -9.365775108337402}, {"x": -31.04683494567871, "y": -19.29154396057129}, {"x": -5.432117938995361, "y": -20.886703491210938}, {"x": 14.247466087341309, "y": 28.561004638671875}, {"x": -21.31106185913086, "y": -9.694003105163574}, {"x": 7.285429000854492, "y": -27.811376571655273}, {"x": 34.12614440917969, "y": -4.234602928161621}, {"x": -30.81889533996582, "y": -19.580238342285156}, {"x": 46.100502014160156, "y": -4.922854900360107}, {"x": 1.3877817392349243, "y": -26.090219497680664}, {"x": -20.980018615722656, "y": 20.332412719726562}, {"x": -2.329571485519409, "y": -17.24911117553711}, {"x": -20.997055053710938, " ...

# %%
#c.categorical_bar_plots()

# %%
c.numeric_boxplot()

# %%
c.numeric_columns_distribution_report()
# Out:
#           Shapiro-Wilks_Test_Statistic  Shapiro-Wilks_p_Value  \
# Pclass                        0.724958           1.011056e-31
# Age                                NaN           1.000000e+00
# SibSp                         0.506108           1.977850e-39
# Parch                         0.536242           1.469814e-38
# Fare                          0.539673           1.859234e-38
# Survived                      0.616424           5.400153e-36
#
#           Normal distribution ?
# Pclass                    False
# Age                        True
# SibSp                     False
# Parch                     False
# Fare                      False
# Survived                  False

# %%
c.probability_plots()

# %%
c.baseline_prediction()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76       137
#            1       0.00      0.00      0.00        86
#
#     accuracy                           0.61       223
#    macro avg       0.31      0.50      0.38       223
# weighted avg       0.38      0.61      0.47       223

# %%
c.transformed_regression()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.436088
#          Iterations: 35
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Survived   No. Observations:                  668
# Model:                          Logit   Df Residuals:                      655
# Method:                           MLE   Df Model:                           12
# Date:                Wed, 02 Oct 2019   Pseudo R-squ.:                  0.3448
# Time:                        22:12:51   Log-Likelihood:                -291.31
# converged:                      False   LL-Null:                       -444.64
# Covariance Type:            nonrobust   LLR p-value:                 1.873e-58
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Pclass_target_encoded     -23.2954      5.771     -4.037      0.000     -34.607     -11.984
# Sex_target_encoded         26.4062      2.251     11.729      0.000      21.993      30.819
# Age_target_encoded          1.1757      0.680      1.728      0.084      -0.158       2.509
# SibSp_target_encoded       -3.1106      2.037     -1.527      0.127      -7.103       0.881
# Parch_target_encoded        0.2703      3.020      0.090      0.929      -5.649       6.190
# Embarked_target_encoded    -3.1410      3.958     -0.794      0.427     -10.898       4.616
# Pclass_imputed_yj          -1.3004      0.199     -6.534      0.000      -1.691      -0.910
# Age_imputed_yj             -0.4596      0.118     -3.909      0.000      -0.690      -0.229
# SibSp_imputed_yj           -0.0407      0.149     -0.273      0.785      -0.334       0.252
# Parch_imputed_yj           -0.1785      0.179     -0.998      0.318      -0.529       0.172
# Fare_imputed_yj             0.5167      0.182      2.840      0.005       0.160       0.873
# missing_Age                 0.1302      0.282      0.462      0.644      -0.422       0.682
# missing_Embarked           18.3227    2.3e+04      0.001      0.999   -4.51e+04    4.52e+04
# ===========================================================================================
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.436088
#          Iterations: 35
#               precision    recall  f1-score   support
#
#            0       0.78      0.86      0.82       137
#            1       0.74      0.62      0.67        86
#
#     accuracy                           0.77       223
#    macro avg       0.76      0.74      0.75       223
# weighted avg       0.76      0.77      0.76       223
