# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import pandas as pd
from crawto.CrawtoDS import CrawtoDS

# %%
df = pd.read_csv("train.csv")
c = CrawtoDS(
    data=df,
    target="Survived",
    problem='classification'
)

# %%
c.nan_report()
# Out:
#              Percent of data encoded NAN
# PassengerId                         0.00
# Survived                            0.00
# Pclass                              0.00
# Name                                0.00
# Sex                                 0.00
# Age                                19.87
# SibSp                               0.00
# Parch                               0.00
# Ticket                              0.00
# Fare                                0.00
# Cabin                              77.10
# Embarked                            0.22

# %%
c.missing_suite()

# %%
c.skew_report()
# Out:
# There are 0 highly skewed data columns. Please check them for miscoded na's
# []

# %%
c.correlation_report()
# Out:
# 'No Features are correlated above the threshold'

# %%
c.target_distribution_report()

# %%
c.tsne()
# Out:
#             <head>
#                 <script type="application/javascript" src="https:\cdnjs.cloudflare.com/ajax/libs/require.js/x.y.z/require.js"></script>
#             </head>
#             <body>
#             <h1> T-sne </h1>
#             <canvas id="t-sne-chart"></canvas>
#             <script>
#             requirejs(['https:\cdnjs.cloudflare.com/ajax/libs/Chart.js/2.8.0/Chart.js'], function(Chart){
#                 new Chart(document.getElementById("t-sne-chart"), {
#                         type: "scatter",
#                         data: {"datasets": [{"label": "0", "data": [{"x": -5.288753032684326, "y": -24.407808303833008}, {"x": 23.01727867126465, "y": 4.880711078643799}, {"x": 17.140270233154297, "y": 14.024622917175293}, {"x": -38.687164306640625, "y": -1.269391417503357}, {"x": -4.044545650482178, "y": -21.258695602416992}, {"x": 22.873332977294922, "y": 5.492485046386719}, {"x": 14.982996940612793, "y": 5.5806756019592285}, {"x": 21.80559539794922, "y": -31.315603256225586}, {"x": 0.07390547543764114, "y": 19.215051651000977}, {"x": 17.46128273010254, "y": 11.92113971710205}, {"x": 20.63652801513672, "y": -31.520263671875}, {"x": 19.506433486938477, "y": -0.33867335319519043}, {"x": -8.496173858642578, "y": -27.617900848388672}, {"x": 33.272674560546875, "y": -25.890316009521484}, {"x": 17.9168701171875, "y": 4.4162163734436035}, {"x": 20.58827018737793, "y": 1.1362183094024658}, {"x": -9.597859382629395, "y": -27.35601234436035}, {"x": -39.48812484741211, "y": -1.0624637603759766}, {"x": 34.529300689697266, "y": -27.495542526245117}, {"x": 13.842848777770996, "y": 10.249032020568848}, {"x": -29.103628158569336, "y": -1.0640106201171875}, {"x": 15.374606132507324, "y": -34.377349853515625}, {"x": 0.42623552680015564, "y": 19.07021713256836}, {"x": 14.263690948486328, "y": 5.244495391845703}, {"x": -11.07180404663086, "y": 23.015365600585938}, {"x": 20.817827224731445, "y": 15.352581977844238}, {"x": -39.24121856689453, "y": 0.14275303483009338}, {"x": -39.321651458740234, "y": -0.4022352397441864}, {"x": -6.945768356323242, "y": 23.85321044921875}, {"x": -11.871460914611816, "y": -23.745275497436523}, {"x": -5.514741897583008, "y": 21.477983474731445}, {"x": -7.663968563079834, "y": 12.981531143188477}, {"x": -3.242281198501587, "y": -24.37989044189453}, {"x": -1.3053046464920044, "y": -22.87769889831543}, {"x": 30.881298065185547, "y": -27.35261344909668}, {"x": -25.281177520751953, "y": 27.231678009033203}, {"x": 14.003684043884277, "y": -29.880521774291992}, {"x": 18.891923904418945, "y": 3.8747992515563965}, {"x": 19.573610305786133, "y": 0.7530087828636169}, {"x": -6.242860317230225, "y": -10.118978500366211}, {"x": 13.376216888427734, "y": 6.042670726776123}, {"x": -7.0950093269348145, "y": 11.898813247680664}, {"x": 16.86834716796875, "y": 14.692070960998535}, {"x": -26.09476089477539, "y": 26.64874839782715}, {"x": 15.430087089538574, "y": 5.505579948425293}, {"x": -1.3901318311691284, "y": 19.804502487182617}, {"x": -1.6017509698867798, "y": -14.939788818359375}, {"x": -9.26235294342041, "y": -29.368947982788086}, {"x": 18.816471099853516, "y": -0.22157298028469086}, {"x": 20.57183837890625, "y": 1.6386362314224243}, {"x": 17.603952407836914, "y": 0.8710389137268066}, {"x": 22.673276901245117, "y": 5.1977739334106445}, {"x": 11.68189525604248, "y": 6.039321422576904}, {"x": -9.327020645141602, "y": -27.10896873474121}, {"x": -4.22128438949585, "y": -21.171878814697266}, {"x": 14.718079566955566, "y": 5.739712238311768}, {"x": -37.74498748779297, "y": -0.4382186532020569}, {"x": 15.430087089538574, "y": 5.505579948425293}, {"x": -4.915802001953125, "y": -24.706218719482422}, {"x": 20.721895217895508, "y": 3.044330358505249}, {"x": -13.801411628723145, "y": 18.02953338623047}, {"x": -0.8182898759841919, "y": 19.585485458374023}, {"x": -39.27805709838867, "y": 0.1475060135126114}, {"x": -22.836181640625, "y": 26.40847396850586}, {"x": -5.308093070983887, "y": -25.037189483642578}, {"x": -30.344755172729492, "y": -1.2694898843765259}, {"x": -7.598869323730469, "y": 21.739057540893555}, {"x": -12.958438873291016, "y": 25.020097732543945}, {"x": 20.366687774658203, "y": 16.396909713745117}, {"x": -4.086738586425781, "y": 21.106176376342773}, {"x": -13.861767768859863, "y": 25.988338470458984}, {"x": -9.4813814163208, "y": -29.062877655029297}, {"x": 19.754467010498047, "y": 2.4545984268188477}, {"x": -2.195485830307007, "y": -22.296546936035156}, {"x": 14.547184944152832, "y": 4.077635288238525}, {"x": -2.28167200088500 ...

# %%
#c.categorical_bar_plots()

# %%
c.numeric_boxplot()

# %%
c.probability_plots()

# %%
c.baseline_prediction()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76       137
#            1       0.00      0.00      0.00        86
#
#     accuracy                           0.61       223
#    macro avg       0.31      0.50      0.38       223
# weighted avg       0.38      0.61      0.47       223

# %%
c.transformed_regression()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.505337
#          Iterations: 35
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Survived   No. Observations:                  668
# Model:                          Logit   Df Residuals:                      655
# Method:                           MLE   Df Model:                           12
# Date:                Thu, 03 Oct 2019   Pseudo R-squ.:                  0.2408
# Time:                        00:41:00   Log-Likelihood:                -337.57
# converged:                      False   LL-Null:                       -444.64
# Covariance Type:            nonrobust   LLR p-value:                 3.880e-39
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Pclass_target_encoded      25.7688      5.363      4.805      0.000      15.258      36.280
# Sex_target_encoded        -57.3254      6.849     -8.370      0.000     -70.749     -43.902
# Age_target_encoded          0.8545      0.665      1.286      0.199      -0.448       2.157
# SibSp_target_encoded        9.2494      3.189      2.900      0.004       2.998      15.501
# Parch_target_encoded       11.0242      4.899      2.250      0.024       1.422      20.626
# Embarked_target_encoded     8.8622      1.970      4.499      0.000       5.001      12.723
# Pclass_imputed_yj           0.0226      0.226      0.100      0.920      -0.420       0.466
# Age_imputed_yj             -0.2991      0.107     -2.802      0.005      -0.508      -0.090
# SibSp_imputed_yj            0.0462      0.116      0.397      0.691      -0.182       0.274
# Parch_imputed_yj           -0.3120      0.182     -1.718      0.086      -0.668       0.044
# Fare_imputed_yj             0.4258      0.187      2.278      0.023       0.060       0.792
# missing_Age                -0.3360      0.275     -1.223      0.221      -0.874       0.202
# missing_Embarked           31.3900   6.71e+06   4.68e-06      1.000   -1.32e+07    1.32e+07
# ===========================================================================================
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.505337
#          Iterations: 35
#               precision    recall  f1-score   support
#
#            0       0.79      0.89      0.84       137
#            1       0.78      0.63      0.70        86
#
#     accuracy                           0.79       223
#    macro avg       0.79      0.76      0.77       223
# weighted avg       0.79      0.79      0.78       223
